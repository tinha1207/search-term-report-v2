# %% [markdown]
# # Search Term Ranker

# %% [markdown]
# ## Search Term Params

# %%
file = r"C:\Users\Tin Ha\Downloads\Tin 7D ST Report (13).xlsx"
min_cvr = .1
min_acos = .001
max_acos = .3
min_clicks = 14
min_orders = 2

# %% [markdown]
# ### Import 7 Day ST Report

# %%
import pandas as pd
import datetime as dt
import os

from config import connect_ods, create_ods_clickhouse_engine

def get_today():
    date = dt.date.today()
    date = date.strftime("%Y-%m-%d")
    return date



def get_productads(date, sales_channel_id=1111, market="US"):
    
    params = {
        "date":date,
        "sales_channel_id":sales_channel_id,
        "market":market
    }
    query = """
        SELECT p.asin as asin, p.sku as sku, p.adgroupid as adgroupid, a.name as adgroupname,  c.name as campaignname
        FROM ods.amz_ads_sp_productads p
        LEFT JOIN ods.amz_ads_sp_adgroups a
        ON a.adgroupid = p.adgroupid
        LEFT JOIN ods.amz_ads_sp_campaigns c
        ON c.campaignid = p.campaignid
        WHERE a.sales_channel_id = %(sales_channel_id)s
        AND p.sales_channel_id = %(sales_channel_id)s
        AND c.sales_channel_id = %(sales_channel_id)s
        AND a.date = %(date)s
        AND c.date = %(date)s
        AND p.date = %(date)s
        AND a.market = %(market)s
        AND c.market = %(market)s
        AND p.market = %(market)s
        AND p.state != 'archived'
        and a.state != 'archived'
        and c.state != 'archived'
        and p.asin IS NOT NULL         
        AND p.campaignid in (
            SELECT campaignid 
            FROM ods.amz_ads_sp_campaigns
            WHERE date = %(date)s
            AND state != 'archived'
            AND market = %(market)s
            AND sales_channel_id = %(sales_channel_id)s
        )
"""
    df = pd.read_sql(query,create_ods_clickhouse_engine(),params=params)
    return df
today = get_today()
df = get_productads(today)
df
# Out:
# success
#              asin                   sku        adgroupid  \
# 0      B06XGBW6VZ  LJ-ZJFRS-030718-02-1  231303828682415
# 1      B06XGBW6VZ  LJ-ZJFRS-030718-02-1  132481476558061
# 2      B06XGBW6VZ  LJ-ZJFRS-030718-02-1  250829557003238
# 3      B07HNVDHK1   LJ-SMSS-092618-01-1  183088933298778
# 4      B07HNVDHK1   LJ-SMSS-092618-01-1  106869446657239
# ...           ...                   ...              ...
# 55941  B00XN0KSDI  LJ-JSDZC-060218-01-1   59669079913778
# 55942  B00XN0KSDI  LJ-JSDZC-060218-01-1   87830829436690
# 55943  B00XN0KSDI  LJ-JSDZC-060218-01-1  130222621462451
# 55944  B00XN0KSDI  LJ-JSDZC-060218-01-1  126511553411317
# 55945  B00XN0KSDI  LJ-JSDZC-060218-01-1  242341729783811
#
#                                             adgroupname  \
# 0      AG_B06XGBW6VZ_M_Exact_congratulations cards bulk
# 1         AG_B06XGBW6VZ_M_Exact_happy anniversary cards
# 2          AG_B06XGBW6VZ_M_Exact_anniversary cards bulk
# 3                AG_B07HNVDHK1_M_Exact_foam ring holder
# 4                      AG_B07HNVDHK1_M_Exact_b07hnwfrdx
# ...                                                 ...
# 55941  AG_B00XN0KSDI_M_Exact_cookie decorating supplies
# 55942          AG_B00XN0KSDI_M_Exact_ginger bread house
# 55943   AG_B00XN0KSDI_M_Exact_gingerbread house cutters
# 55944   AG_B00XN0KSDI_M_Exact_gingerbread man house kit
# 55945   AG_B00XN0KSDI_M_Exact_silicone molds for baking
#
#                           campaignname
# 0      Juvo_AMZUS_B06XGBW6VZ_ISO_Exact
# 1      Juvo_AMZUS_B06XGBW6VZ_ISO_Exact
# 2      Juvo_AMZUS_B06XGBW6VZ_ISO_Exact
# 3      Juvo_AMZUS_B07HNVDHK1_ISO_Exact
# 4      Juvo_AMZUS_B07HNVDHK1_ISO_Exact
# ...                                ...
# 55941  Juvo_AMZUS_B00XN0KSDI_ISO_Exact
# 55942  Juvo_AMZUS_B00XN0KSDI_ISO_Exact
# 55943  Juvo_AMZUS_B00XN0KSDI_ISO_Exact
# 55944  Juvo_AMZUS_B00XN0KSDI_ISO_Exact
# 55945  Juvo_AMZUS_B00XN0KSDI_ISO_Exact
#
# [55946 rows x 5 columns]

# %%
df2 = pd.read_excel(file, parse_dates=["Date"])
df2
# Out:
# c:\users\tin ha\appdata\local\programs\python\python39\lib\site-packages\openpyxl\styles\stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#              Date   Portfolio name Currency  \
# 0      2022-04-19      Tin - QR On      USD
# 1      2022-04-22      Tin - QR On      USD
# 2      2022-04-21      Tin - QR On      USD
# 3      2022-04-21      Tin - QR On      USD
# 4      2022-04-18      Tin - QR On      USD
# ...           ...              ...      ...
# 125992 2022-04-19  + 1 New Stage 1      USD
# 125993 2022-04-22  + 1 New Stage 1      USD
# 125994 2022-04-24  + 1 New Stage 1      USD
# 125995 2022-04-21  + 1 New Stage 1      USD
# 125996 2022-04-24  + 1 New Stage 1      USD
#
#                                        Campaign Name    Ad Group Name  \
# 0       BR_P_B07KC1T8XT_20200331_reserved table sign  AG_P_B07KC1T8XT
# 1       BR_P_B07KC1T8XT_20200331_reserved table sign  AG_P_B07KC1T8XT
# 2       BR_P_B07KC1T8XT_20200331_reserved table sign  AG_P_B07KC1T8XT
# 3       BR_P_B07KC1T8XT_20200331_reserved table sign  AG_P_B07KC1T8XT
# 4       BR_P_B07KC1T8XT_20200331_reserved table sign  AG_P_B07KC1T8XT
# ...                                              ...              ...
# 125992                Juvo_AMZUS_B088BBD9GC_ISO_Auto  AG_B088BBD9GC_A
# 125993                Juvo_AMZUS_B088BBD9GC_ISO_Auto  AG_B088BBD9GC_A
# 125994                Juvo_AMZUS_B088BBD9GC_ISO_Auto  AG_B088BBD9GC_A
# 125995                Juvo_AMZUS_B088BBD9GC_ISO_Auto  AG_B088BBD9GC_A
# 125996                Juvo_AMZUS_B088BBD9GC_ISO_Auto  AG_B088BBD9GC_A
#
#                   Targeting Match Type                 Customer Search Term  \
# 0       reserved table sign      BROAD       gold reserved signs for tables
# 1       reserved table sign      BROAD  heavy metal reserved table top sign
# 2       reserved table sign      BROAD           large reserved table signs
# 3       reserved table sign      BROAD      metal reserved signs for tables
# 4       reserved table sign      BROAD           metal reserved table signs
# ...                     ...        ...                                  ...
# 125992                    *          -               outdoor mats coco coir
# 125993                    *          -               outdoor mats coco coir
# 125994                    *          -               outdoor mats coco coir
# 125995                    *          -                 welcome mats outdoor
# 125996                    *          -                 welcome mats outdoor
#
#         Impressions  Clicks  ...  7 Day Total Sales   \
# 0               3.0     1.0  ...               13.99
# 1               2.0     1.0  ...               13.99
# 2              13.0     1.0  ...                0.00
# 3               1.0     1.0  ...               27.98
# 4               3.0     1.0  ...                0.00
# ...             ...     ...  ...                 ...
# 125992         44.0     1.0  ...               37.98
# 125993         38.0     1.0  ...                0.00
# 125994         43.0     1.0  ...                0.00
# 125995          2.0     1.0  ...                0.00
# 125996         11.0     1.0  ...                0.00
#
#         Total Advertising Cost of Sales (ACOS)   \
# 0                                      0.034310
# 1                                      0.034310
# 2                                           NaN
# 3                                      0.012152
# 4                                           NaN
# ...                                         ...
# 125992                                 0.010795
# 125993                                      NaN
# 125994                                      NaN
# 125995                                      NaN
# 125996                                      NaN
#
#         Total Return on Advertising Spend (ROAS)  7 Day Total Orders (#)  \
# 0                                      29.145833                     1.0
# 1                                      29.145833                     1.0
# 2                                       0.000000                     0.0
# 3                                      82.294118                     1.0
# 4                                       0.000000                     0.0
# ...                                          ...                     ...
# 125992                                 92.634146                     1.0
# 125993                                  0.000000                     0.0
# 125994                                  0.000000                     0.0
# 125995                                  0.000000                     0.0
# 125996                                  0.000000                     0.0
#
#         7 Day Total Units (#)  7 Day Conversion Rate  \
# 0                         1.0                    1.0
# 1                         1.0                    1.0
# 2                         0.0                    0.0
# 3                         2.0                    1.0
# 4                         0.0                    0.0
# ...                       ...                    ...
# 125992                    2.0                    1.0
# 125993                    0.0                    0.0
# 125994                    0.0                    0.0
# 125995                    0.0                    0.0
# 125996                    0.0                    0.0
#
#         7 Day Advertised SKU Units (#)  7 Day Other SKU Units (#)  \
# 0                                  1.0                        0.0
# 1                                  1.0                        0.0
# 2                                  0.0                        0.0
# 3                                  2.0                        0.0
# 4                                  0.0                        0.0
# ...                                ...                        ...
# 125992                             2.0                        0.0
# 125993                             0.0                        0.0
# 125994                             0.0                        0.0
# 125995                             0.0                        0.0
# 125996                             0.0                        0.0
#
#         7 Day Advertised SKU Sales   7 Day Other SKU Sales
# 0                             13.99                     0.0
# 1                             13.99                     0.0
# 2                              0.00                     0.0
# 3                             27.98                     0.0
# 4                              0.00                     0.0
# ...                             ...                     ...
# 125992                        37.98                     0.0
# 125993                         0.00                     0.0
# 125994                         0.00                     0.0
# 125995                         0.00                     0.0
# 125996                         0.00                     0.0
#
# [125997 rows x 23 columns]

# %%
BANNED_CHARS_LIST = [
    "/",
    "-"
]
BANNED_CHARS = "|".join(BANNED_CHARS_LIST)

df3 = df2[df2["Campaign Name"].str.contains("_iso_",case=False)]
df3 = df3[((df3["Match Type"]=="-") & (df3["Targeting"]=="*")) | (df3["Match Type"]=="BROAD")]
df3 = df3[~df3["Customer Search Term"].str.contains(BANNED_CHARS)]
# df3 = df3[df3["Match Type"]=="EXACT"]
df3 = df3.rename(columns={"Ad Group Name":"adgroupname","7 Day Advertised SKU Sales ":"Sales","7 Day Advertised SKU Units (#)":"Orders"})

# %%
df
# Out:
#              asin                   sku        adgroupid  \
# 0      B06XGBW6VZ  LJ-ZJFRS-030718-02-1  231303828682415
# 1      B06XGBW6VZ  LJ-ZJFRS-030718-02-1  132481476558061
# 2      B06XGBW6VZ  LJ-ZJFRS-030718-02-1  250829557003238
# 3      B07HNVDHK1   LJ-SMSS-092618-01-1  183088933298778
# 4      B07HNVDHK1   LJ-SMSS-092618-01-1  106869446657239
# ...           ...                   ...              ...
# 55941  B00XN0KSDI  LJ-JSDZC-060218-01-1   59669079913778
# 55942  B00XN0KSDI  LJ-JSDZC-060218-01-1   87830829436690
# 55943  B00XN0KSDI  LJ-JSDZC-060218-01-1  130222621462451
# 55944  B00XN0KSDI  LJ-JSDZC-060218-01-1  126511553411317
# 55945  B00XN0KSDI  LJ-JSDZC-060218-01-1  242341729783811
#
#                                             adgroupname  \
# 0      AG_B06XGBW6VZ_M_Exact_congratulations cards bulk
# 1         AG_B06XGBW6VZ_M_Exact_happy anniversary cards
# 2          AG_B06XGBW6VZ_M_Exact_anniversary cards bulk
# 3                AG_B07HNVDHK1_M_Exact_foam ring holder
# 4                      AG_B07HNVDHK1_M_Exact_b07hnwfrdx
# ...                                                 ...
# 55941  AG_B00XN0KSDI_M_Exact_cookie decorating supplies
# 55942          AG_B00XN0KSDI_M_Exact_ginger bread house
# 55943   AG_B00XN0KSDI_M_Exact_gingerbread house cutters
# 55944   AG_B00XN0KSDI_M_Exact_gingerbread man house kit
# 55945   AG_B00XN0KSDI_M_Exact_silicone molds for baking
#
#                           campaignname
# 0      Juvo_AMZUS_B06XGBW6VZ_ISO_Exact
# 1      Juvo_AMZUS_B06XGBW6VZ_ISO_Exact
# 2      Juvo_AMZUS_B06XGBW6VZ_ISO_Exact
# 3      Juvo_AMZUS_B07HNVDHK1_ISO_Exact
# 4      Juvo_AMZUS_B07HNVDHK1_ISO_Exact
# ...                                ...
# 55941  Juvo_AMZUS_B00XN0KSDI_ISO_Exact
# 55942  Juvo_AMZUS_B00XN0KSDI_ISO_Exact
# 55943  Juvo_AMZUS_B00XN0KSDI_ISO_Exact
# 55944  Juvo_AMZUS_B00XN0KSDI_ISO_Exact
# 55945  Juvo_AMZUS_B00XN0KSDI_ISO_Exact
#
# [55946 rows x 5 columns]

# %%
df_final = df3.merge(df,how="inner")
df_final = df_final[["Date","asin","Customer Search Term","Impressions","Clicks","Spend","Sales", "Orders"]]
df_final
# Out:
#             Date        asin          Customer Search Term  Impressions  \
# 0     2022-04-22  B07F9J32LM      gaxqfei giant wine glass          6.0
# 1     2022-04-20  B07F9J32LM       giant wine bottle glass         35.0
# 2     2022-04-21  B07F9J32LM  giant mimosa glass 73 ounces          6.0
# 3     2022-04-24  B07F9J32LM  giant mimosa glass 73 ounces          4.0
# 4     2022-04-23  B07F9J32LM    giant mimosa glass plastic          1.0
# ...          ...         ...                           ...          ...
# 94004 2022-04-19  B088BBD9GC        outdoor mats coco coir         44.0
# 94005 2022-04-22  B088BBD9GC        outdoor mats coco coir         38.0
# 94006 2022-04-24  B088BBD9GC        outdoor mats coco coir         43.0
# 94007 2022-04-21  B088BBD9GC          welcome mats outdoor          2.0
# 94008 2022-04-24  B088BBD9GC          welcome mats outdoor         11.0
#
#        Clicks  Spend  Sales  Orders
# 0         1.0   0.35   0.00     0.0
# 1         1.0   0.32  15.99     1.0
# 2         1.0   0.21   0.00     0.0
# 3         2.0   0.44   0.00     0.0
# 4         1.0   0.43   0.00     0.0
# ...       ...    ...    ...     ...
# 94004     1.0   0.41  37.98     2.0
# 94005     1.0   0.53   0.00     0.0
# 94006     1.0   0.45   0.00     0.0
# 94007     1.0   0.53   0.00     0.0
# 94008     1.0   0.53   0.00     0.0
#
# [94009 rows x 8 columns]

# %%
df_final.drop(columns=["Date"],inplace=True)
df_pivot = df_final.groupby(["asin","Customer Search Term"]).sum()
df_pivot["CPC"] = df_pivot.Spend/df_pivot.Clicks
df_pivot["ACOS"] = df_pivot.Spend/df_pivot.Sales
df_pivot["CVR"] = df_pivot.Orders/df_pivot.Clicks

# %%
df_pivot.reset_index(drop=False,inplace=True)

# %%
df_negative = df_pivot[((df_pivot["ACOS"] == float("inf"))|(df_pivot["ACOS"] >= 1)) & (df_pivot["Clicks"]>=min_clicks)]
df_negative.sort_values(by=["Spend"],ascending=False)
# Out:
#              asin                              Customer Search Term  \
# 18214  B07CJJN3PM                           plastic storage drawers
# 73156  B097QQQHPK                         pearl headbands for women
# 62594  B092HPBLPS                                              foam
# 42820  B0899GH58L  120 pcs baby hair ties  cotton toddler hair ties
# 43747  B089GKSWTV                           zipper pull replacement
# ...           ...                                               ...
# 10492  B077JXX15L                                        b083s5y66m
# 24398  B07FKGHKX3                                  knock knock pads
# 43493  B089GF6XXN                                bathroom canisters
# 49511  B08CZ64YKD                                        b09j16g2np
# 63094  B092LPZFP4                                        b07c2zdfmg
#
#        Impressions  Clicks  Spend  Sales  Orders       CPC  ACOS  CVR
# 18214      10448.0    57.0  18.69    0.0     0.0  0.327895   inf  0.0
# 73156       3888.0    54.0  16.45    0.0     0.0  0.304630   inf  0.0
# 62594       2065.0    27.0  15.15    0.0     0.0  0.561111   inf  0.0
# 42820       2021.0    31.0  12.33    0.0     0.0  0.397742   inf  0.0
# 43747       2512.0    17.0  12.18    0.0     0.0  0.716471   inf  0.0
# ...            ...     ...    ...    ...     ...       ...   ...  ...
# 10492        570.0    14.0   2.17    0.0     0.0  0.155000   inf  0.0
# 24398        833.0    15.0   2.01    0.0     0.0  0.134000   inf  0.0
# 43493        346.0    15.0   2.00    0.0     0.0  0.133333   inf  0.0
# 49511        465.0    14.0   1.88    0.0     0.0  0.134286   inf  0.0
# 63094        546.0    16.0   1.62    0.0     0.0  0.101250   inf  0.0
#
# [71 rows x 10 columns]

# %%
df_good = df_pivot[(df_pivot["Clicks"] >= min_clicks) & (df_pivot.ACOS < max_acos) & (df_pivot.Orders >= min_orders) & (df_pivot.ACOS >= min_acos) & (df_pivot.CVR >= min_cvr)].sort_values(["Sales"],ascending=False)
df_good
# Out:
#              asin                               Customer Search Term  \
# 46603  B08BN8T6TB                                        fence slats
# 7370   B073WVH2M3  jekkis 9 inches tall wood easels set of 12 tab...
# 73236  B097SR5571                                         b0881ltfm8
# 73336  B097SS4XNV                                         b087wv4mxy
# 18049  B07CJJN3PM                                         b015dzj8vi
# 46579  B08BN8T6TB                             fence covering privacy
# 56639  B08TR4NC8F                                         b07d3sj7tn
# 72282  B097B39GL7                                    nurse hair ties
# 19794  B07CZXF8WW                                      shrinky dinks
# 76235  B09BC1Y4NN                  thank you bags for business small
# 26850  B07HJ3WCXK                      money gift envelopes for cash
# 74791  B098D8QZNY                                         b07mzhjg3z
# 54695  B08GPRHD5P                                         b083qntcd9
# 34493  B07XSKKV3Y                                         clipboards
# 2373   B01G595N9C                                       baby hangers
# 19793  B07CZXF8WW                                shrinky dink sheets
# 37447  B08318QF9T                   balcony planters railing hanging
# 65130  B093F7ZNSC                                         b07qqwcp3x
# 69706  B095XW75TW                                         b095xwl8yz
# 13103  B07BLMLHFL                                         b07zdntc5n
# 26835  B07HJ3WCXK                      gold money envelopes for cash
# 39904  B085XT4846                                         b07h186t2y
# 7718   B0744FQ9VB                  aisle runner for wedding ceremony
# 47171  B08BR995VC                                         scrunchies
# 58937  B08Z7TYQQM                                         b0000cf8q6
# 2221   B01DLYJ2G4                               poster carrying tube
# 37692  B0832RPNW8                                          door stop
# 35868  B081DVK97F                            badge reels retractable
# 33066  B07W5YKDQZ                                      cubicle hooks
# 64439  B092ZCML3H                          jewelry organizer hanging
# 24345  B07FKGHKX3                                funny post it notes
# 20106  B07D9G4FYC                  first communion favors for guests
# 19789  B07CZXF8WW                                 shrinky dink paper
# 73016  B097QPXL2Y                         padded headbands for women
# 10573  B077JXX15L                               gold paper placemats
# 46787  B08BNC6BSW                    sink hose attachment for faucet
# 45055  B08B1CK27V                                    passport holder
# 26818  B07HJ3WCXK                              eid mubarak envelopes
# 72461  B097D99J87                                 pink throw pillows
# 46919  B08BNQ29BK                                      kitten collar
# 6107   B07232T3H2                                         b07y3x3zbj
# 7222   B073RXQW6M               colorful binder clips assorted sizes
#
#        Impressions  Clicks  Spend   Sales  Orders       CPC      ACOS  \
# 46603        667.0    19.0   6.51  323.91     9.0  0.342632  0.020098
# 7370        2023.0    31.0  24.80  300.92     8.0  0.800000  0.082414
# 73236       1191.0    38.0   8.17  174.93     7.0  0.215000  0.046704
# 73336       1543.0    28.0   9.30  151.96     4.0  0.332143  0.061200
# 18049       4429.0    25.0   8.43  151.96     4.0  0.337200  0.055475
# 46579       2733.0    22.0   7.59  143.96     4.0  0.345000  0.052723
# 56639       2246.0    15.0   7.56  143.96     4.0  0.504000  0.052515
# 72282        369.0    15.0   5.95  129.90    10.0  0.396667  0.045804
# 19794       2146.0    52.0  16.64  129.87    13.0  0.320000  0.128128
# 76235       3481.0    49.0  19.55  107.94     7.0  0.398980  0.181119
# 26850        821.0    29.0   7.76   77.94     6.0  0.267586  0.099564
# 74791        486.0    20.0   5.01   75.98     2.0  0.250500  0.065938
# 54695        998.0    16.0   4.81   67.96     4.0  0.300625  0.070777
# 34493       2146.0    16.0   5.49   65.94     6.0  0.343125  0.083258
# 2373        2887.0    15.0   8.60   59.98     2.0  0.573333  0.143381
# 19793       1091.0    41.0  12.64   59.94     6.0  0.308293  0.210878
# 37447       3109.0    18.0   8.33   56.97     3.0  0.462778  0.146217
# 65130        341.0    18.0   5.38   56.97     3.0  0.298889  0.094436
# 69706        137.0    17.0   3.90   55.96     4.0  0.229412  0.069693
# 13103        607.0    16.0   4.46   53.97     3.0  0.278750  0.082639
# 26835        374.0    15.0   4.10   51.96     4.0  0.273333  0.078907
# 39904        636.0    14.0   1.82   50.97     3.0  0.130000  0.035707
# 7718        3255.0    15.0   4.92   43.98     2.0  0.328000  0.111869
# 47171       1430.0    16.0   6.17   41.97     3.0  0.385625  0.147010
# 58937        783.0    14.0   3.15   37.98     2.0  0.225000  0.082938
# 2221         570.0    14.0   4.32   35.98     2.0  0.308571  0.120067
# 37692        976.0    20.0   7.09   35.97     3.0  0.354500  0.197109
# 35868        607.0    14.0   2.13   32.97     3.0  0.152143  0.064604
# 33066       1236.0    15.0   3.38   32.97     3.0  0.225333  0.102517
# 64439       1309.0    16.0   5.63   31.98     2.0  0.351875  0.176048
# 24345        395.0    16.0   1.94   31.98     2.0  0.121250  0.060663
# 20106        502.0    14.0   2.95   29.98     2.0  0.210714  0.098399
# 19789        757.0    17.0   5.34   29.97     3.0  0.314118  0.178178
# 73016       2312.0    14.0   4.15   27.98     2.0  0.296429  0.148320
# 10573       2521.0    19.0   6.42   27.98     2.0  0.337895  0.229450
# 46787        963.0    15.0   2.80   25.98     2.0  0.186667  0.107775
# 45055        304.0    16.0   3.19   25.98     2.0  0.199375  0.122787
# 26818        486.0    16.0   2.58   25.98     2.0  0.161250  0.099307
# 72461       3138.0    18.0   7.29   25.98     2.0  0.405000  0.280600
# 46919        454.0    20.0   4.52   23.98     2.0  0.226000  0.188490
# 6107         883.0    15.0   4.51   19.98     2.0  0.300667  0.225726
# 7222         386.0    15.0   3.93   17.98     2.0  0.262000  0.218576
#
#             CVR
# 46603  0.473684
# 7370   0.258065
# 73236  0.184211
# 73336  0.142857
# 18049  0.160000
# 46579  0.181818
# 56639  0.266667
# 72282  0.666667
# 19794  0.250000
# 76235  0.142857
# 26850  0.206897
# 74791  0.100000
# 54695  0.250000
# 34493  0.375000
# 2373   0.133333
# 19793  0.146341
# 37447  0.166667
# 65130  0.166667
# 69706  0.235294
# 13103  0.187500
# 26835  0.266667
# 39904  0.214286
# 7718   0.133333
# 47171  0.187500
# 58937  0.142857
# 2221   0.142857
# 37692  0.150000
# 35868  0.214286
# 33066  0.200000
# 64439  0.125000
# 24345  0.125000
# 20106  0.142857
# 19789  0.176471
# 73016  0.142857
# 10573  0.105263
# 46787  0.133333
# 45055  0.125000
# 26818  0.125000
# 72461  0.111111
# 46919  0.100000
# 6107   0.133333
# 7222   0.133333

# %%
new_file = "test2.xlsx"

with pd.ExcelWriter(new_file) as writer:
    df_good.to_excel(writer,index=False,sheet_name="Good")
    df_negative.to_excel(writer,index=False,sheet_name="Negatives")
    df_pivot.to_excel(writer,index=False,sheet_name="Raw Data")

os.system(f"START EXCEL.EXE {new_file}")
# Out:
# 0
